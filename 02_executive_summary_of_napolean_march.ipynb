# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
sns.set_context('talk', font_scale=2)
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# Jorge Camoes has an analysis of [Minard, Tufte, Kosslyn and Godin (and Napoleon)](http://www.excelcharts.com/blog/minard-tufte-kosslyn-godin-napoleon/) that I love.  I don't know if I'll have time to put it in this presentation.
#
# But if I do, I'll need a better version of Camoes's alternative "master graphic":

# %%
plt.figure(figsize=(9,8))
plt.subplots_adjust(hspace=.3, right=.8, left=.1)
colors = np.array(sns.color_palette(n_colors=3))
colors = colors[[0,2]]
plt.pie([2,98], labels=['Survived\n2%', 'Died\n98%'], colors=colors, startangle=0)
plt.savefig('img/napolean2.png')
